# %%
import os
import numpy as np
import keras
from keras import layers, models, optimizers
import matplotlib.pyplot as plt
import tensorflow as tf

# Dataset path
dataset_path = '/content/drive/MyDrive/concave'

# Hyperparameters
IMG_SIZE = 150
BATCH_SIZE = 32
EPOCHS = 100
LEARNING_RATE = 0.0001

# VGG16 Model Architecture
def create_vgg16(input_shape=(150,150, 3), num_classes=2):
    model = models.Sequential(name='VGG16')

    # Block 1
    model.add(layers.Input(shape=input_shape))
    model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', name='block1_conv1'))
    model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', name='block1_conv2'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool'))

    # Block 2
    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='block2_conv1'))
    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='block2_conv2'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool'))

    # Block 3
    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='block3_conv1'))
    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='block3_conv2'))
    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='block3_conv3'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool'))

    # Block 4
    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block4_conv1'))
    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block4_conv2'))
    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block4_conv3'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool'))

    # Block 5
    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block5_conv1'))
    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block5_conv2'))
    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block5_conv3'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool'))

    # Fully Connected Layers
    model.add(layers.Flatten(name='flatten'))
    model.add(layers.Dense(512, activation='relu', name='fc1'))
    model.add(layers.Dropout(0.5, name='dropout1'))
    model.add(layers.Dense(512, activation='relu', name='fc2'))
    model.add(layers.Dropout(0.5, name='dropout2'))
    model.add(layers.Dense(num_classes, activation='softmax', name='predictions'))

    return model

# Data Augmentation Layer
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomTranslation(0.1, 0.1),
], name='data_augmentation')

# Load Training Data
train_ds = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode='categorical'
)

# Load Validation Data
val_ds = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode='categorical'
)

# Get number of classes and class names
class_names = train_ds.class_names
num_classes = len(class_names)
print(f"Number of classes: {num_classes}")
print(f"Class names: {class_names}")

# Normalize pixel values to [0, 1]
normalization_layer = layers.Rescaling(1./255)

# Apply normalization and augmentation
train_ds = train_ds.map(lambda x, y: (data_augmentation(normalization_layer(x), training=True), y))
val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))

# Optimize performance with prefetching
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# Create Model
model = create_vgg16(input_shape=(IMG_SIZE, IMG_SIZE, 3), num_classes=num_classes)

# Compile Model
model.compile(
    optimizer=optimizers.Adam(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Model Summary
model.summary()

# Callbacks
callbacks = [
    keras.callbacks.ModelCheckpoint(
        'vgg16_best_model.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    ),
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-7,
        verbose=1
    )
]

# Train Model
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    validation_data=val_ds,
    callbacks=callbacks,
    verbose=1
)

# Plot Training History
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig('training_history.png')
plt.show()

# Save Final Model
model.save('vgg16_final_model.keras')
print("\nModel training complete and saved!")

# Print class mapping
print(f"\nClass mapping: {dict(enumerate(class_names))}")
# Out:
# Found 900 files belonging to 6 classes.
# Using 720 files for training.
# Found 900 files belonging to 6 classes.
# Using 180 files for validation.
# Number of classes: 6
# Class names: ['Moon_jellyfish', 'barrel_jellyfish', 'blue_jellyfish', 'compass_jellyfish', 'lions_mane_jellyfish', 'mauve_stinger_jellyfish']
# Model: "VGG16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ block1_conv1 (Conv2D)           │ (None, 150, 150, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 150, 150, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 75, 75, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 75, 75, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 37, 37, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 37, 37, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 37, 37, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 18, 18, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 18, 18, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 18, 18, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 18, 18, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 9, 9, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 9, 9, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 9, 9, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 9, 9, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout1 (Dropout)              │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc2 (Dense)                     │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout2 (Dropout)              │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 6)              │         3,078 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,043,558 (23.05 MB)
#  Trainable params: 6,043,558 (23.05 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.1601 - loss: 1.7910
# Epoch 1: val_accuracy improved from -inf to 0.13333, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 690ms/step - accuracy: 0.1596 - loss: 1.7910 - val_accuracy: 0.1333 - val_loss: 1.7932 - learning_rate: 1.0000e-04
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.1597 - loss: 1.7854
# Epoch 2: val_accuracy improved from 0.13333 to 0.15000, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 360ms/step - accuracy: 0.1600 - loss: 1.7855 - val_accuracy: 0.1500 - val_loss: 1.7898 - learning_rate: 1.0000e-04
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.1636 - loss: 1.7845
# Epoch 3: val_accuracy improved from 0.15000 to 0.16111, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 348ms/step - accuracy: 0.1641 - loss: 1.7844 - val_accuracy: 0.1611 - val_loss: 1.7766 - learning_rate: 1.0000e-04
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.2524 - loss: 1.7567
# Epoch 4: val_accuracy improved from 0.16111 to 0.28889, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 330ms/step - accuracy: 0.2522 - loss: 1.7565 - val_accuracy: 0.2889 - val_loss: 1.7042 - learning_rate: 1.0000e-04
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.2274 - loss: 1.7164
# Epoch 5: val_accuracy improved from 0.28889 to 0.32778, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 427ms/step - accuracy: 0.2282 - loss: 1.7163 - val_accuracy: 0.3278 - val_loss: 1.6333 - learning_rate: 1.0000e-04
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.3314 - loss: 1.6458
# Epoch 6: val_accuracy did not improve from 0.32778
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 330ms/step - accuracy: 0.3309 - loss: 1.6454 - val_accuracy: 0.3167 - val_loss: 1.6653 - learning_rate: 1.0000e-04
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.2483 - loss: 1.6491
# Epoch 7: val_accuracy improved from 0.32778 to 0.35000, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 321ms/step - accuracy: 0.2501 - loss: 1.6481 - val_accuracy: 0.3500 - val_loss: 1.5005 - learning_rate: 1.0000e-04
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.3140 - loss: 1.5872
# Epoch 8: val_accuracy did not improve from 0.35000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 346ms/step - accuracy: 0.3148 - loss: 1.5862 - val_accuracy: 0.3222 - val_loss: 1.4697 - learning_rate: 1.0000e-04
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.3000 - loss: 1.5402
# Epoch 9: val_accuracy did not improve from 0.35000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 327ms/step - accuracy: 0.3007 - loss: 1.5402 - val_accuracy: 0.3444 - val_loss: 1.4455 - learning_rate: 1.0000e-04
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.3383 - loss: 1.5517
# Epoch 10: val_accuracy improved from 0.35000 to 0.35556, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 359ms/step - accuracy: 0.3389 - loss: 1.5511 - val_accuracy: 0.3556 - val_loss: 1.5300 - learning_rate: 1.0000e-04
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.3236 - loss: 1.5558
# Epoch 11: val_accuracy did not improve from 0.35556
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 367ms/step - accuracy: 0.3247 - loss: 1.5539 - val_accuracy: 0.3389 - val_loss: 1.4220 - learning_rate: 1.0000e-04
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.3572 - loss: 1.4975
# Epoch 12: val_accuracy improved from 0.35556 to 0.36111, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 322ms/step - accuracy: 0.3577 - loss: 1.4972 - val_accuracy: 0.3611 - val_loss: 1.4602 - learning_rate: 1.0000e-04
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.3186 - loss: 1.4956
# Epoch 13: val_accuracy improved from 0.36111 to 0.37778, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 378ms/step - accuracy: 0.3202 - loss: 1.4946 - val_accuracy: 0.3778 - val_loss: 1.3869 - learning_rate: 1.0000e-04
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.3448 - loss: 1.4620
# Epoch 14: val_accuracy did not improve from 0.37778
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 346ms/step - accuracy: 0.3461 - loss: 1.4617 - val_accuracy: 0.3722 - val_loss: 1.4028 - learning_rate: 1.0000e-04
# Epoch 15/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.3757 - loss: 1.4828
# Epoch 15: val_accuracy improved from 0.37778 to 0.40556, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 321ms/step - accuracy: 0.3769 - loss: 1.4812 - val_accuracy: 0.4056 - val_loss: 1.3344 - learning_rate: 1.0000e-04
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.3985 - loss: 1.3969
# Epoch 16: val_accuracy improved from 0.40556 to 0.41111, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 376ms/step - accuracy: 0.3981 - loss: 1.3980 - val_accuracy: 0.4111 - val_loss: 1.3699 - learning_rate: 1.0000e-04
# Epoch 17/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.3559 - loss: 1.4326
# Epoch 17: val_accuracy did not improve from 0.41111
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 584ms/step - accuracy: 0.3569 - loss: 1.4319 - val_accuracy: 0.4000 - val_loss: 1.3469 - learning_rate: 1.0000e-04
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.4507 - loss: 1.3593
# Epoch 18: val_accuracy improved from 0.41111 to 0.43333, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 15s 336ms/step - accuracy: 0.4506 - loss: 1.3601 - val_accuracy: 0.4333 - val_loss: 1.3554 - learning_rate: 1.0000e-04
# Epoch 19/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.4623 - loss: 1.3779
# Epoch 19: val_accuracy did not improve from 0.43333
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 340ms/step - accuracy: 0.4616 - loss: 1.3777 - val_accuracy: 0.4333 - val_loss: 1.2420 - learning_rate: 1.0000e-04
# Epoch 20/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.4164 - loss: 1.3708
# Epoch 20: val_accuracy did not improve from 0.43333
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 309ms/step - accuracy: 0.4160 - loss: 1.3703 - val_accuracy: 0.4000 - val_loss: 1.2446 - learning_rate: 1.0000e-04
# Epoch 21/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.4220 - loss: 1.3800
# Epoch 21: val_accuracy improved from 0.43333 to 0.45000, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 363ms/step - accuracy: 0.4225 - loss: 1.3787 - val_accuracy: 0.4500 - val_loss: 1.2508 - learning_rate: 1.0000e-04
# Epoch 22/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.4624 - loss: 1.3035
# Epoch 22: val_accuracy improved from 0.45000 to 0.45556, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 335ms/step - accuracy: 0.4624 - loss: 1.3032 - val_accuracy: 0.4556 - val_loss: 1.2313 - learning_rate: 1.0000e-04
# Epoch 23/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.4731 - loss: 1.2582
# Epoch 23: val_accuracy improved from 0.45556 to 0.46667, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 345ms/step - accuracy: 0.4731 - loss: 1.2572 - val_accuracy: 0.4667 - val_loss: 1.3639 - learning_rate: 1.0000e-04
# Epoch 24/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.4994 - loss: 1.2383
# Epoch 24: val_accuracy did not improve from 0.46667
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 344ms/step - accuracy: 0.4993 - loss: 1.2379 - val_accuracy: 0.4667 - val_loss: 1.2639 - learning_rate: 1.0000e-04
# Epoch 25/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.4806 - loss: 1.2863
# Epoch 25: val_accuracy improved from 0.46667 to 0.52778, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 323ms/step - accuracy: 0.4812 - loss: 1.2847 - val_accuracy: 0.5278 - val_loss: 1.1094 - learning_rate: 1.0000e-04
# Epoch 26/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.5256 - loss: 1.1421
# Epoch 26: val_accuracy did not improve from 0.52778
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 351ms/step - accuracy: 0.5242 - loss: 1.1456 - val_accuracy: 0.5056 - val_loss: 1.1796 - learning_rate: 1.0000e-04
# Epoch 27/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.5089 - loss: 1.2271
# Epoch 27: val_accuracy did not improve from 0.52778
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 322ms/step - accuracy: 0.5091 - loss: 1.2267 - val_accuracy: 0.4556 - val_loss: 1.1752 - learning_rate: 1.0000e-04
# Epoch 28/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.5435 - loss: 1.1637
# Epoch 28: val_accuracy did not improve from 0.52778
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 341ms/step - accuracy: 0.5430 - loss: 1.1648 - val_accuracy: 0.5222 - val_loss: 1.1065 - learning_rate: 1.0000e-04
# Epoch 29/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.5423 - loss: 1.1829
# Epoch 29: val_accuracy did not improve from 0.52778
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 348ms/step - accuracy: 0.5423 - loss: 1.1824 - val_accuracy: 0.5000 - val_loss: 1.2749 - learning_rate: 1.0000e-04
# Epoch 30/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.5284 - loss: 1.1335
# Epoch 30: val_accuracy improved from 0.52778 to 0.53333, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 332ms/step - accuracy: 0.5284 - loss: 1.1344 - val_accuracy: 0.5333 - val_loss: 1.0787 - learning_rate: 1.0000e-04
# Epoch 31/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.5444 - loss: 1.1369
# Epoch 31: val_accuracy improved from 0.53333 to 0.55556, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 329ms/step - accuracy: 0.5438 - loss: 1.1376 - val_accuracy: 0.5556 - val_loss: 1.1350 - learning_rate: 1.0000e-04
# Epoch 32/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.5541 - loss: 1.1032
# Epoch 32: val_accuracy improved from 0.55556 to 0.58333, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 408ms/step - accuracy: 0.5547 - loss: 1.1031 - val_accuracy: 0.5833 - val_loss: 1.1047 - learning_rate: 1.0000e-04
# Epoch 33/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.5759 - loss: 1.0802
# Epoch 33: val_accuracy did not improve from 0.58333
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 302ms/step - accuracy: 0.5765 - loss: 1.0806 - val_accuracy: 0.5444 - val_loss: 1.1411 - learning_rate: 1.0000e-04
# Epoch 34/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.5843 - loss: 1.0801
# Epoch 34: val_accuracy did not improve from 0.58333
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 344ms/step - accuracy: 0.5840 - loss: 1.0802 - val_accuracy: 0.5611 - val_loss: 1.0485 - learning_rate: 1.0000e-04
# Epoch 35/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.5719 - loss: 1.0101
# Epoch 35: val_accuracy did not improve from 0.58333
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 331ms/step - accuracy: 0.5727 - loss: 1.0101 - val_accuracy: 0.5056 - val_loss: 1.0813 - learning_rate: 1.0000e-04
# Epoch 36/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.5883 - loss: 1.0573
# Epoch 36: val_accuracy did not improve from 0.58333
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 313ms/step - accuracy: 0.5886 - loss: 1.0570 - val_accuracy: 0.5611 - val_loss: 1.0184 - learning_rate: 1.0000e-04
# Epoch 37/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.6344 - loss: 0.9657
# Epoch 37: val_accuracy improved from 0.58333 to 0.60556, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 358ms/step - accuracy: 0.6335 - loss: 0.9667 - val_accuracy: 0.6056 - val_loss: 0.9989 - learning_rate: 1.0000e-04
# Epoch 38/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.6278 - loss: 0.9539
# Epoch 38: val_accuracy did not improve from 0.60556
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 306ms/step - accuracy: 0.6276 - loss: 0.9542 - val_accuracy: 0.5333 - val_loss: 1.1445 - learning_rate: 1.0000e-04
# Epoch 39/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.6299 - loss: 0.9726
# Epoch 39: val_accuracy improved from 0.60556 to 0.61667, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 358ms/step - accuracy: 0.6283 - loss: 0.9744 - val_accuracy: 0.6167 - val_loss: 1.0059 - learning_rate: 1.0000e-04
# Epoch 40/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.5996 - loss: 0.9969
# Epoch 40: val_accuracy did not improve from 0.61667
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 340ms/step - accuracy: 0.5999 - loss: 0.9964 - val_accuracy: 0.5667 - val_loss: 0.9709 - learning_rate: 1.0000e-04
# Epoch 41/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.6569 - loss: 0.8876
# Epoch 41: val_accuracy improved from 0.61667 to 0.62778, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 324ms/step - accuracy: 0.6555 - loss: 0.8891 - val_accuracy: 0.6278 - val_loss: 1.0031 - learning_rate: 1.0000e-04
# Epoch 42/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.6259 - loss: 0.9406
# Epoch 42: val_accuracy improved from 0.62778 to 0.65556, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 355ms/step - accuracy: 0.6257 - loss: 0.9413 - val_accuracy: 0.6556 - val_loss: 0.9102 - learning_rate: 1.0000e-04
# Epoch 43/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.6411 - loss: 0.8354
# Epoch 43: val_accuracy did not improve from 0.65556
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 306ms/step - accuracy: 0.6410 - loss: 0.8361 - val_accuracy: 0.6556 - val_loss: 0.9081 - learning_rate: 1.0000e-04
# Epoch 44/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.6462 - loss: 0.8805
# Epoch 44: val_accuracy did not improve from 0.65556
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 343ms/step - accuracy: 0.6457 - loss: 0.8814 - val_accuracy: 0.6444 - val_loss: 0.9925 - learning_rate: 1.0000e-04
# Epoch 45/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.6600 - loss: 0.8490
# Epoch 45: val_accuracy did not improve from 0.65556
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 323ms/step - accuracy: 0.6603 - loss: 0.8503 - val_accuracy: 0.5889 - val_loss: 0.9983 - learning_rate: 1.0000e-04
# Epoch 46/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.6666 - loss: 0.8259
# Epoch 46: val_accuracy improved from 0.65556 to 0.66111, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 341ms/step - accuracy: 0.6673 - loss: 0.8258 - val_accuracy: 0.6611 - val_loss: 0.9579 - learning_rate: 1.0000e-04
# Epoch 47/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.6467 - loss: 0.8936
# Epoch 47: val_accuracy did not improve from 0.66111
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 359ms/step - accuracy: 0.6469 - loss: 0.8930 - val_accuracy: 0.6556 - val_loss: 0.9219 - learning_rate: 1.0000e-04
# Epoch 48/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.6886 - loss: 0.7738
# Epoch 48: val_accuracy did not improve from 0.66111
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 323ms/step - accuracy: 0.6893 - loss: 0.7736 - val_accuracy: 0.6056 - val_loss: 0.9232 - learning_rate: 1.0000e-04
# Epoch 49/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.7079 - loss: 0.7597
# Epoch 49: val_accuracy improved from 0.66111 to 0.68889, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 385ms/step - accuracy: 0.7077 - loss: 0.7599 - val_accuracy: 0.6889 - val_loss: 0.7783 - learning_rate: 5.0000e-05
# Epoch 50/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.7451 - loss: 0.6909
# Epoch 50: val_accuracy did not improve from 0.68889
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 377ms/step - accuracy: 0.7445 - loss: 0.6926 - val_accuracy: 0.6611 - val_loss: 0.7416 - learning_rate: 5.0000e-05
# Epoch 51/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.7354 - loss: 0.6729
# Epoch 51: val_accuracy improved from 0.68889 to 0.69444, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 359ms/step - accuracy: 0.7358 - loss: 0.6722 - val_accuracy: 0.6944 - val_loss: 0.7367 - learning_rate: 5.0000e-05
# Epoch 52/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.7450 - loss: 0.7011
# Epoch 52: val_accuracy improved from 0.69444 to 0.70556, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 392ms/step - accuracy: 0.7449 - loss: 0.7001 - val_accuracy: 0.7056 - val_loss: 0.7777 - learning_rate: 5.0000e-05
# Epoch 53/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.7424 - loss: 0.6790
# Epoch 53: val_accuracy did not improve from 0.70556
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 388ms/step - accuracy: 0.7425 - loss: 0.6784 - val_accuracy: 0.6667 - val_loss: 0.7399 - learning_rate: 5.0000e-05
# Epoch 54/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.7634 - loss: 0.5897
# Epoch 54: val_accuracy did not improve from 0.70556
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 342ms/step - accuracy: 0.7633 - loss: 0.5898 - val_accuracy: 0.6944 - val_loss: 0.7549 - learning_rate: 5.0000e-05
# Epoch 55/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.7213 - loss: 0.7213
# Epoch 55: val_accuracy did not improve from 0.70556
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 356ms/step - accuracy: 0.7216 - loss: 0.7205 - val_accuracy: 0.7056 - val_loss: 0.7749 - learning_rate: 5.0000e-05
# Epoch 56/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.7278 - loss: 0.6749
# Epoch 56: val_accuracy did not improve from 0.70556
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 374ms/step - accuracy: 0.7282 - loss: 0.6744 - val_accuracy: 0.6611 - val_loss: 0.8059 - learning_rate: 5.0000e-05
# Epoch 57/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.7513 - loss: 0.6024
# Epoch 57: val_accuracy did not improve from 0.70556
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 327ms/step - accuracy: 0.7521 - loss: 0.6016 - val_accuracy: 0.7056 - val_loss: 0.7641 - learning_rate: 2.5000e-05
# Epoch 58/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.7776 - loss: 0.5779
# Epoch 58: val_accuracy improved from 0.70556 to 0.71667, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 396ms/step - accuracy: 0.7780 - loss: 0.5767 - val_accuracy: 0.7167 - val_loss: 0.7310 - learning_rate: 2.5000e-05
# Epoch 59/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.7747 - loss: 0.5431
# Epoch 59: val_accuracy improved from 0.71667 to 0.74444, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 389ms/step - accuracy: 0.7743 - loss: 0.5433 - val_accuracy: 0.7444 - val_loss: 0.7074 - learning_rate: 2.5000e-05
# Epoch 60/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.7638 - loss: 0.5726
# Epoch 60: val_accuracy did not improve from 0.74444
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 336ms/step - accuracy: 0.7645 - loss: 0.5718 - val_accuracy: 0.7167 - val_loss: 0.6774 - learning_rate: 2.5000e-05
# Epoch 61/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.7864 - loss: 0.5533
# Epoch 61: val_accuracy improved from 0.74444 to 0.75000, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 403ms/step - accuracy: 0.7862 - loss: 0.5540 - val_accuracy: 0.7500 - val_loss: 0.6024 - learning_rate: 2.5000e-05
# Epoch 62/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.8106 - loss: 0.5151
# Epoch 62: val_accuracy improved from 0.75000 to 0.76111, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 397ms/step - accuracy: 0.8108 - loss: 0.5151 - val_accuracy: 0.7611 - val_loss: 0.6888 - learning_rate: 2.5000e-05
# Epoch 63/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.8224 - loss: 0.4848
# Epoch 63: val_accuracy did not improve from 0.76111
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 336ms/step - accuracy: 0.8227 - loss: 0.4841 - val_accuracy: 0.7333 - val_loss: 0.7177 - learning_rate: 2.5000e-05
# Epoch 64/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.8046 - loss: 0.5393
# Epoch 64: val_accuracy did not improve from 0.76111
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 387ms/step - accuracy: 0.8040 - loss: 0.5397 - val_accuracy: 0.7333 - val_loss: 0.6952 - learning_rate: 2.5000e-05
# Epoch 65/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.7977 - loss: 0.5406
# Epoch 65: val_accuracy improved from 0.76111 to 0.77778, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 375ms/step - accuracy: 0.7976 - loss: 0.5400 - val_accuracy: 0.7778 - val_loss: 0.6389 - learning_rate: 2.5000e-05
# Epoch 66/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.8258 - loss: 0.4787
# Epoch 66: val_accuracy improved from 0.77778 to 0.78333, saving model to vgg16_best_model.keras
#
# Epoch 66: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 360ms/step - accuracy: 0.8256 - loss: 0.4786 - val_accuracy: 0.7833 - val_loss: 0.6657 - learning_rate: 2.5000e-05
# Epoch 67/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.8117 - loss: 0.4952
# Epoch 67: val_accuracy did not improve from 0.78333
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 382ms/step - accuracy: 0.8117 - loss: 0.4941 - val_accuracy: 0.7833 - val_loss: 0.6494 - learning_rate: 1.2500e-05
# Epoch 68/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.8154 - loss: 0.4563
# Epoch 68: val_accuracy did not improve from 0.78333
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 354ms/step - accuracy: 0.8160 - loss: 0.4557 - val_accuracy: 0.7667 - val_loss: 0.7106 - learning_rate: 1.2500e-05
# Epoch 69/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.8205 - loss: 0.4779
# Epoch 69: val_accuracy did not improve from 0.78333
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 334ms/step - accuracy: 0.8208 - loss: 0.4781 - val_accuracy: 0.7667 - val_loss: 0.6543 - learning_rate: 1.2500e-05
# Epoch 70/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.8208 - loss: 0.4526
# Epoch 70: val_accuracy improved from 0.78333 to 0.79444, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 394ms/step - accuracy: 0.8213 - loss: 0.4519 - val_accuracy: 0.7944 - val_loss: 0.6272 - learning_rate: 1.2500e-05
# Epoch 71/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.8402 - loss: 0.4383
# Epoch 71: val_accuracy did not improve from 0.79444
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 332ms/step - accuracy: 0.8397 - loss: 0.4397 - val_accuracy: 0.7833 - val_loss: 0.6021 - learning_rate: 1.2500e-05
# Epoch 72/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.8279 - loss: 0.4444
# Epoch 72: val_accuracy did not improve from 0.79444
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 366ms/step - accuracy: 0.8280 - loss: 0.4442 - val_accuracy: 0.7889 - val_loss: 0.6175 - learning_rate: 1.2500e-05
# Epoch 73/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.8194 - loss: 0.4339
# Epoch 73: val_accuracy did not improve from 0.79444
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 366ms/step - accuracy: 0.8199 - loss: 0.4336 - val_accuracy: 0.7944 - val_loss: 0.5929 - learning_rate: 1.2500e-05
# Epoch 74/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.8480 - loss: 0.3868
# Epoch 74: val_accuracy improved from 0.79444 to 0.80000, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 338ms/step - accuracy: 0.8477 - loss: 0.3880 - val_accuracy: 0.8000 - val_loss: 0.6046 - learning_rate: 1.2500e-05
# Epoch 75/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.8547 - loss: 0.3892
# Epoch 75: val_accuracy did not improve from 0.80000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 11s 347ms/step - accuracy: 0.8543 - loss: 0.3899 - val_accuracy: 0.7722 - val_loss: 0.6413 - learning_rate: 1.2500e-05
# Epoch 76/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.8499 - loss: 0.4106
# Epoch 76: val_accuracy did not improve from 0.80000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 367ms/step - accuracy: 0.8493 - loss: 0.4117 - val_accuracy: 0.7944 - val_loss: 0.6274 - learning_rate: 1.2500e-05
# Epoch 77/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.8378 - loss: 0.4097
# Epoch 77: val_accuracy did not improve from 0.80000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 323ms/step - accuracy: 0.8377 - loss: 0.4104 - val_accuracy: 0.7889 - val_loss: 0.5956 - learning_rate: 1.2500e-05
# Epoch 78/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.8596 - loss: 0.3701
# Epoch 78: val_accuracy did not improve from 0.80000
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 371ms/step - accuracy: 0.8593 - loss: 0.3710 - val_accuracy: 0.7778 - val_loss: 0.6128 - learning_rate: 1.2500e-05
# Epoch 79/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8540 - loss: 0.3668
# Epoch 79: val_accuracy did not improve from 0.80000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 360ms/step - accuracy: 0.8540 - loss: 0.3669 - val_accuracy: 0.8000 - val_loss: 0.5916 - learning_rate: 6.2500e-06
# Epoch 80/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.8631 - loss: 0.3706
# Epoch 80: val_accuracy did not improve from 0.80000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 325ms/step - accuracy: 0.8633 - loss: 0.3703 - val_accuracy: 0.7889 - val_loss: 0.6449 - learning_rate: 6.2500e-06
# Epoch 81/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.8631 - loss: 0.3797
# Epoch 81: val_accuracy did not improve from 0.80000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 370ms/step - accuracy: 0.8631 - loss: 0.3797 - val_accuracy: 0.7944 - val_loss: 0.5767 - learning_rate: 6.2500e-06
# Epoch 82/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.8474 - loss: 0.4018
# Epoch 82: val_accuracy did not improve from 0.80000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 325ms/step - accuracy: 0.8476 - loss: 0.4018 - val_accuracy: 0.8000 - val_loss: 0.5872 - learning_rate: 6.2500e-06
# Epoch 83/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.8926 - loss: 0.3330
# Epoch 83: val_accuracy did not improve from 0.80000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 353ms/step - accuracy: 0.8919 - loss: 0.3341 - val_accuracy: 0.8000 - val_loss: 0.6187 - learning_rate: 6.2500e-06
# Epoch 84/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.8381 - loss: 0.3687
# Epoch 84: val_accuracy did not improve from 0.80000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 372ms/step - accuracy: 0.8384 - loss: 0.3679 - val_accuracy: 0.8000 - val_loss: 0.6133 - learning_rate: 6.2500e-06
# Epoch 85/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.8384 - loss: 0.4305
# Epoch 85: val_accuracy improved from 0.80000 to 0.81667, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 343ms/step - accuracy: 0.8389 - loss: 0.4298 - val_accuracy: 0.8167 - val_loss: 0.5372 - learning_rate: 6.2500e-06
# Epoch 86/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.8350 - loss: 0.4581
# Epoch 86: val_accuracy did not improve from 0.81667
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 376ms/step - accuracy: 0.8360 - loss: 0.4548 - val_accuracy: 0.8000 - val_loss: 0.5920 - learning_rate: 6.2500e-06
# Epoch 87/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.8382 - loss: 0.3915
# Epoch 87: val_accuracy did not improve from 0.81667
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 355ms/step - accuracy: 0.8388 - loss: 0.3913 - val_accuracy: 0.8111 - val_loss: 0.5767 - learning_rate: 6.2500e-06
# Epoch 88/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.8508 - loss: 0.3863
# Epoch 88: val_accuracy did not improve from 0.81667
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 326ms/step - accuracy: 0.8501 - loss: 0.3876 - val_accuracy: 0.8056 - val_loss: 0.5443 - learning_rate: 6.2500e-06
# Epoch 89/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.8368 - loss: 0.3934
# Epoch 89: val_accuracy did not improve from 0.81667
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 372ms/step - accuracy: 0.8376 - loss: 0.3924 - val_accuracy: 0.8000 - val_loss: 0.5506 - learning_rate: 6.2500e-06
# Epoch 90/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.8309 - loss: 0.4248
# Epoch 90: val_accuracy did not improve from 0.81667
#
# Epoch 90: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 343ms/step - accuracy: 0.8314 - loss: 0.4251 - val_accuracy: 0.7944 - val_loss: 0.5511 - learning_rate: 6.2500e-06
# Epoch 91/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.8621 - loss: 0.3328
# Epoch 91: val_accuracy did not improve from 0.81667
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 340ms/step - accuracy: 0.8627 - loss: 0.3325 - val_accuracy: 0.8111 - val_loss: 0.5398 - learning_rate: 3.1250e-06
# Epoch 92/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.8313 - loss: 0.4213
# Epoch 92: val_accuracy did not improve from 0.81667
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 366ms/step - accuracy: 0.8317 - loss: 0.4200 - val_accuracy: 0.8056 - val_loss: 0.5484 - learning_rate: 3.1250e-06
# Epoch 93/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.8675 - loss: 0.3680
# Epoch 93: val_accuracy did not improve from 0.81667
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 341ms/step - accuracy: 0.8673 - loss: 0.3686 - val_accuracy: 0.8000 - val_loss: 0.5427 - learning_rate: 3.1250e-06
# Epoch 94/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.8379 - loss: 0.3840
# Epoch 94: val_accuracy did not improve from 0.81667
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 338ms/step - accuracy: 0.8386 - loss: 0.3831 - val_accuracy: 0.7889 - val_loss: 0.5660 - learning_rate: 3.1250e-06
# Epoch 95/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.8663 - loss: 0.3651
# Epoch 95: val_accuracy did not improve from 0.81667
#
# Epoch 95: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 379ms/step - accuracy: 0.8661 - loss: 0.3654 - val_accuracy: 0.8000 - val_loss: 0.5694 - learning_rate: 3.1250e-06
# Epoch 95: early stopping
# Restoring model weights from the end of the best epoch: 85.
# Model training complete and saved!
#
# Class mapping: {0: 'Moon_jellyfish', 1: 'barrel_jellyfish', 2: 'blue_jellyfish', 3: 'compass_jellyfish', 4: 'lions_mane_jellyfish', 5: 'mauve_stinger_jellyfish'}

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# Get predictions on validation set (using the model already in memory)
y_true = []
y_pred = []

for images, labels in val_ds:
    predictions = model.predict(images, verbose=0)
    y_pred.extend(np.argmax(predictions, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))

y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Generate Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Plot Confusion Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names,
            cbar_kws={'label': 'Count'})
plt.title('Confusion Matrix', fontsize=16, fontweight='bold')
plt.ylabel('True Label', fontsize=12)
plt.xlabel('Predicted Label', fontsize=12)
plt.tight_layout()
plt.show()

# Print Classification Report
print("\n" + "="*60)
print("CLASSIFICATION REPORT")
print("="*60)
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

# Calculate and display additional metrics
print("\n" + "="*60)
print("DETAILED METRICS PER CLASS")
print("="*60)

for i, class_name in enumerate(class_names):
    class_mask = (y_true == i)
    total = np.sum(class_mask)
    correct = np.sum((y_true == i) & (y_pred == i))
    accuracy = correct / total if total > 0 else 0

    print(f"\n{class_name}:")
    print(f"  Total samples: {total}")
    print(f"  Correctly classified: {correct}")
    print(f"  Accuracy: {accuracy:.4f} ({accuracy*100:.2f}%)")

# Overall Accuracy
overall_accuracy = np.sum(y_true == y_pred) / len(y_true)
print("\n" + "="*60)
print(f"OVERALL ACCURACY: {overall_accuracy:.4f} ({overall_accuracy*100:.2f}%)")
print("="*60)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7c1a80357d80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ============================================================
# CLASSIFICATION REPORT
# ============================================================
#                          precision    recall  f1-score   support
#
#          Moon_jellyfish     0.8750    0.7778    0.8235        36
#        barrel_jellyfish     0.8077    0.8750    0.8400        24
#          blue_jellyfish     0.8333    0.7895    0.8108        38
#       compass_jellyfish     0.9333    0.8235    0.8750        34
#    lions_mane_jellyfish     0.6786    0.9500    0.7917        20
# mauve_stinger_jellyfish     0.7500    0.7500    0.7500        28
#
#                accuracy                         0.8167       180
#               macro avg     0.8130    0.8276    0.8152       180
#            weighted avg     0.8270    0.8167    0.8178       180
#
#
# ============================================================
# DETAILED METRICS PER CLASS
# ============================================================
#
# Moon_jellyfish:
#   Total samples: 36
#   Correctly classified: 28
#   Accuracy: 0.7778 (77.78%)
#
# barrel_jellyfish:
#   Total samples: 24
#   Correctly classified: 21
#   Accuracy: 0.8750 (87.50%)
#
# blue_jellyfish:
#   Total samples: 38
#   Correctly classified: 30
#   Accuracy: 0.7895 (78.95%)
#
# compass_jellyfish:
#   Total samples: 34
#   Correctly classified: 28
#   Accuracy: 0.8235 (82.35%)
#
# lions_mane_jellyfish:
#   Total samples: 20
#   Correctly classified: 19
#   Accuracy: 0.9500 (95.00%)
#
# mauve_stinger_jellyfish:
#   Total samples: 28
#   Correctly classified: 21
#   Accuracy: 0.7500 (75.00%)
#
# ============================================================
# OVERALL ACCURACY: 0.8167 (81.67%)
# ============================================================
