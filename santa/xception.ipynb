# %%
import os
import numpy as np
import keras
from keras import layers, models, optimizers
from keras.preprocessing import image_dataset_from_directory
import matplotlib.pyplot as plt
import tensorflow as tf

# Configuration
DATASET_PATH = "/content/drive/MyDrive/concave"
IMG_SIZE = (150, 150)  # Smaller size for small datasets
BATCH_SIZE = 16  # Smaller batch for small datasets
EPOCHS = 100
INITIAL_LR = 0.0001

# Load dataset
print("Loading dataset...")
train_ds = image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_ds = image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

# Get class names and number of classes
class_names = train_ds.class_names
num_classes = len(class_names)
print(f"Classes found: {class_names}")
print(f"Number of classes: {num_classes}")

# Count total samples
train_samples = tf.data.experimental.cardinality(train_ds).numpy() * BATCH_SIZE
val_samples = tf.data.experimental.cardinality(val_ds).numpy() * BATCH_SIZE
print(f"Training samples: ~{train_samples}")
print(f"Validation samples: ~{val_samples}")

# Optimize dataset performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# Stronger data augmentation for small datasets
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomFlip("vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.2),
    layers.RandomBrightness(0.2),
], name="data_augmentation")


# Lightweight Xception-inspired model for small datasets
def create_lightweight_xception(input_shape=(150, 150, 3), num_classes=2):
    """
    Lightweight Xception architecture optimized for small datasets
    """
    inputs = layers.Input(shape=input_shape)

    # Data augmentation (only during training)
    x = data_augmentation(inputs)

    # Rescale pixel values to [0, 1]
    x = layers.Rescaling(1./255)(x)

    # Entry flow - reduced filters
    x = layers.Conv2D(32, 3, strides=2, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    # First Xception block
    residual = layers.Conv2D(64, 1, strides=2, padding='same')(x)
    x = layers.SeparableConv2D(64, 3, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.SeparableConv2D(64, 3, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(3, strides=2, padding='same')(x)
    x = layers.add([x, residual])

    # Second Xception block
    residual = layers.Conv2D(128, 1, strides=2, padding='same')(x)
    x = layers.Activation('relu')(x)
    x = layers.SeparableConv2D(128, 3, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.SeparableConv2D(128, 3, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(3, strides=2, padding='same')(x)
    x = layers.add([x, residual])

    # Third Xception block
    residual = layers.Conv2D(256, 1, strides=2, padding='same')(x)
    x = layers.Activation('relu')(x)
    x = layers.SeparableConv2D(256, 3, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.SeparableConv2D(256, 3, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(3, strides=2, padding='same')(x)
    x = layers.add([x, residual])

    # Global pooling and classification
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(128, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01))(x)
    x = layers.Dropout(0.5)(x)

    if num_classes == 2:
        outputs = layers.Dense(1, activation='sigmoid')(x)
    else:
        outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs, name='lightweight_xception')
    return model


# Create model
print("\nCreating lightweight Xception model...")
model = create_lightweight_xception(input_shape=(*IMG_SIZE, 3), num_classes=num_classes)

# Compile model
if num_classes == 2:
    loss = keras.losses.BinaryCrossentropy()
    metrics = ['accuracy', keras.metrics.AUC(name='auc')]
else:
    loss = keras.losses.SparseCategoricalCrossentropy()
    metrics = ['accuracy']

model.compile(
    optimizer=optimizers.Adam(learning_rate=INITIAL_LR),
    loss=loss,
    metrics=metrics
)

# Model summary
print(model.summary())

# Callbacks with more aggressive learning rate schedule
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=15,
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-7,
        verbose=1
    ),
    keras.callbacks.ModelCheckpoint(
        'best_xception_model.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

# Train model
print("\nTraining model...")
print("=" * 50)
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)

# Plot training history
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Accuracy plot
axes[0].plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[0].plot(history.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[0].set_title('Model Accuracy', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Accuracy', fontsize=12)
axes[0].legend(fontsize=10)
axes[0].grid(True, alpha=0.3)

# Loss plot
axes[1].plot(history.history['loss'], label='Train Loss', linewidth=2)
axes[1].plot(history.history['val_loss'], label='Val Loss', linewidth=2)
axes[1].set_title('Model Loss', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Loss', fontsize=12)
axes[1].legend(fontsize=10)
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('training_history.png', dpi=150)
plt.show()

# Evaluate model
print("\n" + "=" * 50)
print("Final Evaluation:")
print("=" * 50)
results = model.evaluate(val_ds, verbose=1)
print(f"\nValidation Results:")
for name, value in zip(model.metrics_names, results):
    print(f"  {name}: {value:.4f}")

# Save final model
model.save('xception_model_final.keras')
print("\n✓ Model saved as 'xception_model_final.keras'")
print("✓ Best model saved as 'best_xception_model.keras'")

# Print best validation accuracy from history
best_val_acc = max(history.history['val_accuracy'])
best_epoch = history.history['val_accuracy'].index(best_val_acc) + 1
print(f"\n✓ Best validation accuracy: {best_val_acc:.4f} at epoch {best_epoch}")
# Out:
# Loading dataset...
# Found 900 files belonging to 6 classes.
# Using 720 files for training.
# Found 900 files belonging to 6 classes.
# Using 180 files for validation.
# Classes found: ['Moon_jellyfish', 'barrel_jellyfish', 'blue_jellyfish', 'compass_jellyfish', 'lions_mane_jellyfish', 'mauve_stinger_jellyfish']
# Number of classes: 6
# Training samples: ~720
# Validation samples: ~192
#
# Creating lightweight Xception model...
# Model: "lightweight_xception"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_11      │ (None, 150, 150,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ data_augmentation   │ (None, 150, 150,  │          0 │ input_layer_11[0… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_5         │ (None, 150, 150,  │          0 │ data_augmentatio… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 75, 75,    │        864 │ rescaling_5[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 75, 75,    │        128 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 75, 75,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_60 │ (None, 75, 75,    │      2,336 │ activation_21[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 75, 75,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 75, 75,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_61 │ (None, 75, 75,    │      4,672 │ activation_22[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 75, 75,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_18    │ (None, 38, 38,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 38, 38,    │      2,112 │ activation_21[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_24 (Add)        │ (None, 38, 38,    │          0 │ max_pooling2d_18… │
# │                     │ 64)               │            │ conv2d_28[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 38, 38,    │          0 │ add_24[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_62 │ (None, 38, 38,    │      8,768 │ activation_23[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 38, 38,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 38, 38,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_63 │ (None, 38, 38,    │     17,536 │ activation_24[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 38, 38,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_19    │ (None, 19, 19,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 19, 19,    │      8,320 │ add_24[0][0]      │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_25 (Add)        │ (None, 19, 19,    │          0 │ max_pooling2d_19… │
# │                     │ 128)              │            │ conv2d_29[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 19, 19,    │          0 │ add_25[0][0]      │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_64 │ (None, 19, 19,    │     33,920 │ activation_25[0]… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 19, 19,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 19, 19,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_65 │ (None, 19, 19,    │     67,840 │ activation_26[0]… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 19, 19,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_20    │ (None, 10, 10,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 10, 10,    │     33,024 │ add_25[0][0]      │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 10, 10,    │          0 │ max_pooling2d_20… │
# │                     │ 256)              │            │ conv2d_30[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ add_26[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │     32,896 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 128)       │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 6)         │        774 │ dropout_4[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 216,774 (846.77 KB)
#  Trainable params: 214,918 (839.52 KB)
#  Non-trainable params: 1,856 (7.25 KB)
# None
#
# Training model...
# ==================================================
# Epoch 1/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1925 - loss: 4.6806
# Epoch 1: val_accuracy improved from -inf to 0.25000, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 14s 109ms/step - accuracy: 0.1922 - loss: 4.6787 - val_accuracy: 0.2500 - val_loss: 3.4839 - learning_rate: 1.0000e-04
# Epoch 2/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.2052 - loss: 4.1247
# Epoch 2: val_accuracy did not improve from 0.25000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.2055 - loss: 4.1235 - val_accuracy: 0.2222 - val_loss: 3.4699 - learning_rate: 1.0000e-04
# Epoch 3/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.1777 - loss: 3.9995
# Epoch 3: val_accuracy did not improve from 0.25000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.1783 - loss: 3.9983 - val_accuracy: 0.2278 - val_loss: 3.4584 - learning_rate: 1.0000e-04
# Epoch 4/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2286 - loss: 3.7285
# Epoch 4: val_accuracy did not improve from 0.25000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.2287 - loss: 3.7269 - val_accuracy: 0.2111 - val_loss: 3.4467 - learning_rate: 1.0000e-04
# Epoch 5/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2344 - loss: 3.6588
# Epoch 5: val_accuracy did not improve from 0.25000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.2344 - loss: 3.6587 - val_accuracy: 0.2167 - val_loss: 3.4348 - learning_rate: 1.0000e-04
# Epoch 6/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2613 - loss: 3.6285
# Epoch 6: val_accuracy did not improve from 0.25000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.2615 - loss: 3.6273 - val_accuracy: 0.2444 - val_loss: 3.4216 - learning_rate: 1.0000e-04
# Epoch 7/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.2844 - loss: 3.5043
# Epoch 7: val_accuracy did not improve from 0.25000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.2829 - loss: 3.5052 - val_accuracy: 0.2056 - val_loss: 3.4090 - learning_rate: 1.0000e-04
# Epoch 8/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2677 - loss: 3.4625
# Epoch 8: val_accuracy did not improve from 0.25000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.2680 - loss: 3.4608 - val_accuracy: 0.2056 - val_loss: 3.3909 - learning_rate: 1.0000e-04
# Epoch 9/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2730 - loss: 3.4331
# Epoch 9: val_accuracy did not improve from 0.25000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.2731 - loss: 3.4317 - val_accuracy: 0.2000 - val_loss: 3.3678 - learning_rate: 1.0000e-04
# Epoch 10/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2977 - loss: 3.2862
# Epoch 10: val_accuracy did not improve from 0.25000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.2979 - loss: 3.2864 - val_accuracy: 0.2111 - val_loss: 3.3306 - learning_rate: 1.0000e-04
# Epoch 11/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3170 - loss: 3.2591
# Epoch 11: val_accuracy did not improve from 0.25000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.3168 - loss: 3.2596 - val_accuracy: 0.2389 - val_loss: 3.2768 - learning_rate: 1.0000e-04
# Epoch 12/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3070 - loss: 3.3058
# Epoch 12: val_accuracy improved from 0.25000 to 0.34444, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.3073 - loss: 3.3047 - val_accuracy: 0.3444 - val_loss: 3.1976 - learning_rate: 1.0000e-04
# Epoch 13/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3062 - loss: 3.1876
# Epoch 13: val_accuracy improved from 0.34444 to 0.37778, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.3063 - loss: 3.1875 - val_accuracy: 0.3778 - val_loss: 3.1287 - learning_rate: 1.0000e-04
# Epoch 14/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.2948 - loss: 3.2406
# Epoch 14: val_accuracy improved from 0.37778 to 0.44444, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2965 - loss: 3.2382 - val_accuracy: 0.4444 - val_loss: 3.0497 - learning_rate: 1.0000e-04
# Epoch 15/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.3744 - loss: 3.0670
# Epoch 15: val_accuracy improved from 0.44444 to 0.45000, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.3741 - loss: 3.0674 - val_accuracy: 0.4500 - val_loss: 2.9871 - learning_rate: 1.0000e-04
# Epoch 16/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3569 - loss: 3.0817
# Epoch 16: val_accuracy did not improve from 0.45000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.3566 - loss: 3.0821 - val_accuracy: 0.4389 - val_loss: 2.9584 - learning_rate: 1.0000e-04
# Epoch 17/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3839 - loss: 3.0657
# Epoch 17: val_accuracy improved from 0.45000 to 0.45556, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3834 - loss: 3.0661 - val_accuracy: 0.4556 - val_loss: 2.9285 - learning_rate: 1.0000e-04
# Epoch 18/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3732 - loss: 3.0380
# Epoch 18: val_accuracy did not improve from 0.45556
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.3735 - loss: 3.0378 - val_accuracy: 0.4111 - val_loss: 2.9262 - learning_rate: 1.0000e-04
# Epoch 19/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3719 - loss: 3.0757
# Epoch 19: val_accuracy did not improve from 0.45556
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.3720 - loss: 3.0750 - val_accuracy: 0.4222 - val_loss: 2.8759 - learning_rate: 1.0000e-04
# Epoch 20/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.3597 - loss: 2.9891
# Epoch 20: val_accuracy did not improve from 0.45556
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.3608 - loss: 2.9878 - val_accuracy: 0.4333 - val_loss: 2.8888 - learning_rate: 1.0000e-04
# Epoch 21/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3463 - loss: 3.0301
# Epoch 21: val_accuracy did not improve from 0.45556
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.3464 - loss: 3.0300 - val_accuracy: 0.4444 - val_loss: 2.8348 - learning_rate: 1.0000e-04
# Epoch 22/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3627 - loss: 2.9535
# Epoch 22: val_accuracy did not improve from 0.45556
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.3634 - loss: 2.9528 - val_accuracy: 0.4167 - val_loss: 2.8606 - learning_rate: 1.0000e-04
# Epoch 23/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3771 - loss: 2.9479
# Epoch 23: val_accuracy improved from 0.45556 to 0.48333, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.3774 - loss: 2.9469 - val_accuracy: 0.4833 - val_loss: 2.7878 - learning_rate: 1.0000e-04
# Epoch 24/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4050 - loss: 2.9116
# Epoch 24: val_accuracy did not improve from 0.48333
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.4047 - loss: 2.9117 - val_accuracy: 0.4722 - val_loss: 2.7476 - learning_rate: 1.0000e-04
# Epoch 25/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4184 - loss: 2.9268
# Epoch 25: val_accuracy did not improve from 0.48333
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.4184 - loss: 2.9255 - val_accuracy: 0.4722 - val_loss: 2.7411 - learning_rate: 1.0000e-04
# Epoch 26/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.3983 - loss: 2.8456
# Epoch 26: val_accuracy did not improve from 0.48333
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.3984 - loss: 2.8454 - val_accuracy: 0.4222 - val_loss: 2.7880 - learning_rate: 1.0000e-04
# Epoch 27/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4040 - loss: 2.8112
# Epoch 27: val_accuracy improved from 0.48333 to 0.51667, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.4044 - loss: 2.8112 - val_accuracy: 0.5167 - val_loss: 2.6866 - learning_rate: 1.0000e-04
# Epoch 28/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.3760 - loss: 2.8256
# Epoch 28: val_accuracy did not improve from 0.51667
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3763 - loss: 2.8254 - val_accuracy: 0.5056 - val_loss: 2.6640 - learning_rate: 1.0000e-04
# Epoch 29/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4639 - loss: 2.7054
# Epoch 29: val_accuracy did not improve from 0.51667
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.4634 - loss: 2.7057 - val_accuracy: 0.4889 - val_loss: 2.6373 - learning_rate: 1.0000e-04
# Epoch 30/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4267 - loss: 2.7372
# Epoch 30: val_accuracy did not improve from 0.51667
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.4268 - loss: 2.7369 - val_accuracy: 0.4833 - val_loss: 2.6280 - learning_rate: 1.0000e-04
# Epoch 31/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4266 - loss: 2.7480
# Epoch 31: val_accuracy did not improve from 0.51667
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.4268 - loss: 2.7476 - val_accuracy: 0.4778 - val_loss: 2.6528 - learning_rate: 1.0000e-04
# Epoch 32/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4270 - loss: 2.7115
# Epoch 32: val_accuracy did not improve from 0.51667
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.4273 - loss: 2.7109 - val_accuracy: 0.5056 - val_loss: 2.5914 - learning_rate: 1.0000e-04
# Epoch 33/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4685 - loss: 2.7020
# Epoch 33: val_accuracy did not improve from 0.51667
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.4683 - loss: 2.7015 - val_accuracy: 0.4722 - val_loss: 2.6229 - learning_rate: 1.0000e-04
# Epoch 34/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4481 - loss: 2.7013
# Epoch 34: val_accuracy improved from 0.51667 to 0.52222, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.4479 - loss: 2.7001 - val_accuracy: 0.5222 - val_loss: 2.5322 - learning_rate: 1.0000e-04
# Epoch 35/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.4556 - loss: 2.6394
# Epoch 35: val_accuracy did not improve from 0.52222
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.4548 - loss: 2.6395 - val_accuracy: 0.5056 - val_loss: 2.5302 - learning_rate: 1.0000e-04
# Epoch 36/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4463 - loss: 2.5880
# Epoch 36: val_accuracy did not improve from 0.52222
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.4463 - loss: 2.5879 - val_accuracy: 0.4833 - val_loss: 2.4809 - learning_rate: 1.0000e-04
# Epoch 37/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4758 - loss: 2.5579
# Epoch 37: val_accuracy did not improve from 0.52222
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.4758 - loss: 2.5578 - val_accuracy: 0.4556 - val_loss: 2.5904 - learning_rate: 1.0000e-04
# Epoch 38/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4860 - loss: 2.5570
# Epoch 38: val_accuracy did not improve from 0.52222
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.4858 - loss: 2.5566 - val_accuracy: 0.5167 - val_loss: 2.4735 - learning_rate: 1.0000e-04
# Epoch 39/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4492 - loss: 2.5789
# Epoch 39: val_accuracy improved from 0.52222 to 0.54444, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.4494 - loss: 2.5782 - val_accuracy: 0.5444 - val_loss: 2.4055 - learning_rate: 1.0000e-04
# Epoch 40/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4572 - loss: 2.5108
# Epoch 40: val_accuracy did not improve from 0.54444
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.4579 - loss: 2.5099 - val_accuracy: 0.5278 - val_loss: 2.4529 - learning_rate: 1.0000e-04
# Epoch 41/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5146 - loss: 2.5127
# Epoch 41: val_accuracy improved from 0.54444 to 0.57222, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.5136 - loss: 2.5132 - val_accuracy: 0.5722 - val_loss: 2.3434 - learning_rate: 1.0000e-04
# Epoch 42/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4991 - loss: 2.4730
# Epoch 42: val_accuracy did not improve from 0.57222
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.4989 - loss: 2.4727 - val_accuracy: 0.5278 - val_loss: 2.3457 - learning_rate: 1.0000e-04
# Epoch 43/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5080 - loss: 2.4219
# Epoch 43: val_accuracy did not improve from 0.57222
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.5076 - loss: 2.4220 - val_accuracy: 0.5500 - val_loss: 2.3064 - learning_rate: 1.0000e-04
# Epoch 44/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5423 - loss: 2.4084
# Epoch 44: val_accuracy did not improve from 0.57222
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.5419 - loss: 2.4083 - val_accuracy: 0.5278 - val_loss: 2.3504 - learning_rate: 1.0000e-04
# Epoch 45/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5462 - loss: 2.3136
# Epoch 45: val_accuracy did not improve from 0.57222
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.5459 - loss: 2.3141 - val_accuracy: 0.5444 - val_loss: 2.3192 - learning_rate: 1.0000e-04
# Epoch 46/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5152 - loss: 2.3837
# Epoch 46: val_accuracy did not improve from 0.57222
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.5151 - loss: 2.3831 - val_accuracy: 0.5278 - val_loss: 2.3012 - learning_rate: 1.0000e-04
# Epoch 47/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5796 - loss: 2.2764
# Epoch 47: val_accuracy did not improve from 0.57222
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.5784 - loss: 2.2768 - val_accuracy: 0.5000 - val_loss: 2.3673 - learning_rate: 1.0000e-04
# Epoch 48/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5176 - loss: 2.2889
# Epoch 48: val_accuracy did not improve from 0.57222
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.5172 - loss: 2.2901 - val_accuracy: 0.5333 - val_loss: 2.2703 - learning_rate: 1.0000e-04
# Epoch 49/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5153 - loss: 2.2793
# Epoch 49: val_accuracy did not improve from 0.57222
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.5154 - loss: 2.2792 - val_accuracy: 0.5000 - val_loss: 2.3514 - learning_rate: 1.0000e-04
# Epoch 50/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5128 - loss: 2.2985
# Epoch 50: val_accuracy did not improve from 0.57222
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.5135 - loss: 2.2978 - val_accuracy: 0.5056 - val_loss: 2.2536 - learning_rate: 1.0000e-04
# Epoch 51/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5647 - loss: 2.2928
# Epoch 51: val_accuracy did not improve from 0.57222
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.5638 - loss: 2.2919 - val_accuracy: 0.5389 - val_loss: 2.2649 - learning_rate: 1.0000e-04
# Epoch 52/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5369 - loss: 2.2380
# Epoch 52: val_accuracy did not improve from 0.57222
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.5370 - loss: 2.2373 - val_accuracy: 0.5444 - val_loss: 2.1396 - learning_rate: 1.0000e-04
# Epoch 53/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5865 - loss: 2.1837
# Epoch 53: val_accuracy did not improve from 0.57222
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.5862 - loss: 2.1836 - val_accuracy: 0.5389 - val_loss: 2.1707 - learning_rate: 1.0000e-04
# Epoch 54/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5253 - loss: 2.2085
# Epoch 54: val_accuracy did not improve from 0.57222
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.5254 - loss: 2.2080 - val_accuracy: 0.5389 - val_loss: 2.1215 - learning_rate: 1.0000e-04
# Epoch 55/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5736 - loss: 2.1705
# Epoch 55: val_accuracy improved from 0.57222 to 0.57778, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.5733 - loss: 2.1701 - val_accuracy: 0.5778 - val_loss: 2.0985 - learning_rate: 1.0000e-04
# Epoch 56/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5580 - loss: 2.1591
# Epoch 56: val_accuracy did not improve from 0.57778
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.5581 - loss: 2.1589 - val_accuracy: 0.5278 - val_loss: 2.1401 - learning_rate: 1.0000e-04
# Epoch 57/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5957 - loss: 2.1268
# Epoch 57: val_accuracy improved from 0.57778 to 0.58889, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.5953 - loss: 2.1263 - val_accuracy: 0.5889 - val_loss: 2.0646 - learning_rate: 1.0000e-04
# Epoch 58/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6074 - loss: 2.0551
# Epoch 58: val_accuracy did not improve from 0.58889
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.6069 - loss: 2.0555 - val_accuracy: 0.5778 - val_loss: 2.0712 - learning_rate: 1.0000e-04
# Epoch 59/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5768 - loss: 2.0956
# Epoch 59: val_accuracy improved from 0.58889 to 0.60000, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.5771 - loss: 2.0945 - val_accuracy: 0.6000 - val_loss: 2.0039 - learning_rate: 1.0000e-04
# Epoch 60/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6037 - loss: 2.0474
# Epoch 60: val_accuracy did not improve from 0.60000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.6035 - loss: 2.0471 - val_accuracy: 0.5889 - val_loss: 2.0111 - learning_rate: 1.0000e-04
# Epoch 61/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6097 - loss: 2.0203
# Epoch 61: val_accuracy improved from 0.60000 to 0.61667, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.6089 - loss: 2.0212 - val_accuracy: 0.6167 - val_loss: 1.9761 - learning_rate: 1.0000e-04
# Epoch 62/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5851 - loss: 2.0254
# Epoch 62: val_accuracy did not improve from 0.61667
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.5848 - loss: 2.0256 - val_accuracy: 0.5833 - val_loss: 2.0312 - learning_rate: 1.0000e-04
# Epoch 63/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6126 - loss: 1.9882
# Epoch 63: val_accuracy did not improve from 0.61667
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.6123 - loss: 1.9882 - val_accuracy: 0.6167 - val_loss: 1.8638 - learning_rate: 1.0000e-04
# Epoch 64/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6309 - loss: 1.9327
# Epoch 64: val_accuracy improved from 0.61667 to 0.62778, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.6303 - loss: 1.9332 - val_accuracy: 0.6278 - val_loss: 1.9149 - learning_rate: 1.0000e-04
# Epoch 65/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5879 - loss: 1.9656
# Epoch 65: val_accuracy did not improve from 0.62778
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.5884 - loss: 1.9641 - val_accuracy: 0.6278 - val_loss: 1.9572 - learning_rate: 1.0000e-04
# Epoch 66/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6348 - loss: 1.8978
# Epoch 66: val_accuracy did not improve from 0.62778
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.6345 - loss: 1.8980 - val_accuracy: 0.6278 - val_loss: 1.8867 - learning_rate: 1.0000e-04
# Epoch 67/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5794 - loss: 1.9157
# Epoch 67: val_accuracy did not improve from 0.62778
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.5792 - loss: 1.9171 - val_accuracy: 0.5222 - val_loss: 1.8931 - learning_rate: 1.0000e-04
# Epoch 68/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6164 - loss: 1.9624
# Epoch 68: val_accuracy did not improve from 0.62778
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.6167 - loss: 1.9612 - val_accuracy: 0.5778 - val_loss: 1.8612 - learning_rate: 1.0000e-04
# Epoch 69/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6038 - loss: 1.9004
# Epoch 69: val_accuracy did not improve from 0.62778
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.6041 - loss: 1.8997 - val_accuracy: 0.5611 - val_loss: 1.8652 - learning_rate: 1.0000e-04
# Epoch 70/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6286 - loss: 1.8689
# Epoch 70: val_accuracy did not improve from 0.62778
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.6281 - loss: 1.8691 - val_accuracy: 0.6056 - val_loss: 1.8264 - learning_rate: 1.0000e-04
# Epoch 71/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5894 - loss: 1.9140
# Epoch 71: val_accuracy did not improve from 0.62778
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.5893 - loss: 1.9136 - val_accuracy: 0.6111 - val_loss: 1.8382 - learning_rate: 1.0000e-04
# Epoch 72/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6395 - loss: 1.8300
# Epoch 72: val_accuracy improved from 0.62778 to 0.63333, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6391 - loss: 1.8302 - val_accuracy: 0.6333 - val_loss: 1.7781 - learning_rate: 1.0000e-04
# Epoch 73/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6351 - loss: 1.7785
# Epoch 73: val_accuracy did not improve from 0.63333
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.6348 - loss: 1.7784 - val_accuracy: 0.6167 - val_loss: 1.8195 - learning_rate: 1.0000e-04
# Epoch 74/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6193 - loss: 1.8094
# Epoch 74: val_accuracy did not improve from 0.63333
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.6198 - loss: 1.8084 - val_accuracy: 0.6111 - val_loss: 1.7498 - learning_rate: 1.0000e-04
# Epoch 75/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6499 - loss: 1.7377
# Epoch 75: val_accuracy improved from 0.63333 to 0.65000, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.6497 - loss: 1.7378 - val_accuracy: 0.6500 - val_loss: 1.7295 - learning_rate: 1.0000e-04
# Epoch 76/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6554 - loss: 1.7601
# Epoch 76: val_accuracy did not improve from 0.65000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.6551 - loss: 1.7605 - val_accuracy: 0.6333 - val_loss: 1.7367 - learning_rate: 1.0000e-04
# Epoch 77/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6129 - loss: 1.7884
# Epoch 77: val_accuracy improved from 0.65000 to 0.65556, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.6128 - loss: 1.7884 - val_accuracy: 0.6556 - val_loss: 1.6733 - learning_rate: 1.0000e-04
# Epoch 78/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6662 - loss: 1.6860
# Epoch 78: val_accuracy did not improve from 0.65556
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.6656 - loss: 1.6869 - val_accuracy: 0.5889 - val_loss: 1.7540 - learning_rate: 1.0000e-04
# Epoch 79/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6334 - loss: 1.7085
# Epoch 79: val_accuracy did not improve from 0.65556
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.6332 - loss: 1.7086 - val_accuracy: 0.6500 - val_loss: 1.6794 - learning_rate: 1.0000e-04
# Epoch 80/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6150 - loss: 1.6976
# Epoch 80: val_accuracy improved from 0.65556 to 0.67778, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.6152 - loss: 1.6974 - val_accuracy: 0.6778 - val_loss: 1.6159 - learning_rate: 1.0000e-04
# Epoch 81/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6407 - loss: 1.7354
# Epoch 81: val_accuracy did not improve from 0.67778
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.6401 - loss: 1.7343 - val_accuracy: 0.5889 - val_loss: 1.8952 - learning_rate: 1.0000e-04
# Epoch 82/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6412 - loss: 1.6853
# Epoch 82: val_accuracy did not improve from 0.67778
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.6413 - loss: 1.6851 - val_accuracy: 0.6667 - val_loss: 1.6505 - learning_rate: 1.0000e-04
# Epoch 83/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6903 - loss: 1.6442
# Epoch 83: val_accuracy did not improve from 0.67778
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.6893 - loss: 1.6437 - val_accuracy: 0.6500 - val_loss: 1.6310 - learning_rate: 1.0000e-04
# Epoch 84/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6520 - loss: 1.6216
# Epoch 84: val_accuracy did not improve from 0.67778
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.6520 - loss: 1.6216 - val_accuracy: 0.6556 - val_loss: 1.6995 - learning_rate: 1.0000e-04
# Epoch 85/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6406 - loss: 1.6057
# Epoch 85: val_accuracy did not improve from 0.67778
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.6409 - loss: 1.6055 - val_accuracy: 0.6333 - val_loss: 1.5912 - learning_rate: 1.0000e-04
# Epoch 86/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7006 - loss: 1.6110
# Epoch 86: val_accuracy did not improve from 0.67778
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.7003 - loss: 1.6106 - val_accuracy: 0.6333 - val_loss: 1.5988 - learning_rate: 1.0000e-04
# Epoch 87/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6880 - loss: 1.5326
# Epoch 87: val_accuracy did not improve from 0.67778
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.6873 - loss: 1.5338 - val_accuracy: 0.5944 - val_loss: 1.6028 - learning_rate: 1.0000e-04
# Epoch 88/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6509 - loss: 1.5993
# Epoch 88: val_accuracy improved from 0.67778 to 0.69444, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6510 - loss: 1.5990 - val_accuracy: 0.6944 - val_loss: 1.4821 - learning_rate: 1.0000e-04
# Epoch 89/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6923 - loss: 1.5856
# Epoch 89: val_accuracy did not improve from 0.69444
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.6921 - loss: 1.5853 - val_accuracy: 0.6667 - val_loss: 1.5043 - learning_rate: 1.0000e-04
# Epoch 90/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7011 - loss: 1.5086
# Epoch 90: val_accuracy improved from 0.69444 to 0.70556, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.6997 - loss: 1.5098 - val_accuracy: 0.7056 - val_loss: 1.4674 - learning_rate: 1.0000e-04
# Epoch 91/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7068 - loss: 1.4957
# Epoch 91: val_accuracy improved from 0.70556 to 0.71667, saving model to best_xception_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.7062 - loss: 1.4959 - val_accuracy: 0.7167 - val_loss: 1.4893 - learning_rate: 1.0000e-04
# Epoch 92/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6953 - loss: 1.4856
# Epoch 92: val_accuracy did not improve from 0.71667
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6953 - loss: 1.4859 - val_accuracy: 0.6444 - val_loss: 1.6746 - learning_rate: 1.0000e-04
# Epoch 93/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7204 - loss: 1.4894
# Epoch 93: val_accuracy did not improve from 0.71667
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.7191 - loss: 1.4909 - val_accuracy: 0.6000 - val_loss: 1.6026 - learning_rate: 1.0000e-04
# Epoch 94/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7211 - loss: 1.4551
# Epoch 94: val_accuracy did not improve from 0.71667
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.7208 - loss: 1.4552 - val_accuracy: 0.6611 - val_loss: 1.5131 - learning_rate: 1.0000e-04
# Epoch 95/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6941 - loss: 1.4664
# Epoch 95: val_accuracy did not improve from 0.71667
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.6938 - loss: 1.4668 - val_accuracy: 0.6500 - val_loss: 1.4627 - learning_rate: 1.0000e-04
# Epoch 96/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6813 - loss: 1.4621
# Epoch 96: val_accuracy did not improve from 0.71667
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.6814 - loss: 1.4622 - val_accuracy: 0.7000 - val_loss: 1.4680 - learning_rate: 1.0000e-04
# Epoch 97/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7011 - loss: 1.4781
# Epoch 97: val_accuracy did not improve from 0.71667
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.7008 - loss: 1.4778 - val_accuracy: 0.6556 - val_loss: 1.4395 - learning_rate: 1.0000e-04
# Epoch 98/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6790 - loss: 1.5247
# Epoch 98: val_accuracy did not improve from 0.71667
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6789 - loss: 1.5241 - val_accuracy: 0.6944 - val_loss: 1.4341 - learning_rate: 1.0000e-04
# Epoch 99/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7288 - loss: 1.3807
# Epoch 99: val_accuracy did not improve from 0.71667
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.7283 - loss: 1.3813 - val_accuracy: 0.6667 - val_loss: 1.3759 - learning_rate: 1.0000e-04
# Epoch 100/100
# 44/45 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7094 - loss: 1.4026
# Epoch 100: val_accuracy did not improve from 0.71667
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.7093 - loss: 1.4036 - val_accuracy: 0.6667 - val_loss: 1.4363 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 91.
# ==================================================
# Final Evaluation:
# ==================================================
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7260 - loss: 1.4550
#
# Validation Results:
#   loss: 1.4893
#   compile_metrics: 0.7167
#
# ✓ Model saved as 'xception_model_final.keras'
# ✓ Best model saved as 'best_xception_model.keras'
#
# ✓ Best validation accuracy: 0.7167 at epoch 91
