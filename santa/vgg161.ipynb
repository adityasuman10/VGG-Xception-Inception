# %%
import os
import numpy as np
import keras
from keras import layers, models, optimizers
import matplotlib.pyplot as plt
import tensorflow as tf

# Dataset path
dataset_path = '/content/drive/MyDrive/concave'

# Hyperparameters
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 50
LEARNING_RATE = 0.0001

# VGG16 Model Architecture
def create_vgg16(input_shape=(224, 224, 3), num_classes=2):
    model = models.Sequential(name='VGG16')

    # Block 1
    model.add(layers.Input(shape=input_shape))
    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1'))
    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool'))

    # Block 2
    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1'))
    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool'))

    # Block 3
    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1'))
    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2'))
    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool'))

    # Block 4
    model.add(layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1'))
    model.add(layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2'))
    model.add(layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool'))

    # Block 5
    model.add(layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1'))
    model.add(layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2'))
    model.add(layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool'))

    # Fully Connected Layers
    model.add(layers.Flatten(name='flatten'))
    model.add(layers.Dense(4096, activation='relu', name='fc1'))
    model.add(layers.Dropout(0.5, name='dropout1'))
    model.add(layers.Dense(4096, activation='relu', name='fc2'))
    model.add(layers.Dropout(0.5, name='dropout2'))
    model.add(layers.Dense(num_classes, activation='softmax', name='predictions'))

    return model

# Data Augmentation Layer
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomTranslation(0.1, 0.1),
], name='data_augmentation')

# Load Training Data
train_ds = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode='categorical'
)

# Load Validation Data
val_ds = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode='categorical'
)

# Get number of classes and class names
class_names = train_ds.class_names
num_classes = len(class_names)
print(f"Number of classes: {num_classes}")
print(f"Class names: {class_names}")

# Normalize pixel values to [0, 1]
normalization_layer = layers.Rescaling(1./255)

# Apply normalization and augmentation
train_ds = train_ds.map(lambda x, y: (data_augmentation(normalization_layer(x), training=True), y))
val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))

# Optimize performance with prefetching
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# Create Model
model = create_vgg16(input_shape=(IMG_SIZE, IMG_SIZE, 3), num_classes=num_classes)

# Compile Model
model.compile(
    optimizer=optimizers.Adam(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Model Summary
model.summary()

# Callbacks
callbacks = [
    keras.callbacks.ModelCheckpoint(
        'vgg16_best_model.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    ),
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-7,
        verbose=1
    )
]

# Train Model
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    validation_data=val_ds,
    callbacks=callbacks,
    verbose=1
)

# Plot Training History
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig('training_history.png')
plt.show()

# Save Final Model
model.save('vgg16_final_model.keras')
print("\nModel training complete and saved!")

# Print class mapping
print(f"\nClass mapping: {dict(enumerate(class_names))}")
# Out:
# Found 900 files belonging to 6 classes.
# Using 720 files for training.
# Found 900 files belonging to 6 classes.
# Using 180 files for validation.
# Number of classes: 6
# Class names: ['Moon_jellyfish', 'barrel_jellyfish', 'blue_jellyfish', 'compass_jellyfish', 'lions_mane_jellyfish', 'mauve_stinger_jellyfish']
# Model: "VGG16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 4096)           │   102,764,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout1 (Dropout)              │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc2 (Dense)                     │ (None, 4096)           │    16,781,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout2 (Dropout)              │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 6)              │        24,582 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 134,285,126 (512.26 MB)
#  Trainable params: 134,285,126 (512.26 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.1698 - loss: 1.7921
# Epoch 1: val_accuracy improved from -inf to 0.13333, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 285s 10s/step - accuracy: 0.1692 - loss: 1.7921 - val_accuracy: 0.1333 - val_loss: 1.7862 - learning_rate: 1.0000e-04
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.2310 - loss: 1.7578
# Epoch 2: val_accuracy improved from 0.13333 to 0.21111, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.2318 - loss: 1.7581 - val_accuracy: 0.2111 - val_loss: 1.7654 - learning_rate: 1.0000e-04
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 826ms/step - accuracy: 0.2537 - loss: 1.7036
# Epoch 3: val_accuracy improved from 0.21111 to 0.27222, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.2545 - loss: 1.7037 - val_accuracy: 0.2722 - val_loss: 1.6532 - learning_rate: 1.0000e-04
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 840ms/step - accuracy: 0.3067 - loss: 1.6331
# Epoch 4: val_accuracy improved from 0.27222 to 0.35556, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.3077 - loss: 1.6314 - val_accuracy: 0.3556 - val_loss: 1.6062 - learning_rate: 1.0000e-04
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 815ms/step - accuracy: 0.3710 - loss: 1.5197
# Epoch 5: val_accuracy improved from 0.35556 to 0.38333, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.3711 - loss: 1.5192 - val_accuracy: 0.3833 - val_loss: 1.5532 - learning_rate: 1.0000e-04
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 842ms/step - accuracy: 0.3765 - loss: 1.5123
# Epoch 6: val_accuracy did not improve from 0.38333
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 895ms/step - accuracy: 0.3764 - loss: 1.5115 - val_accuracy: 0.3722 - val_loss: 1.5566 - learning_rate: 1.0000e-04
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 829ms/step - accuracy: 0.3941 - loss: 1.4523
# Epoch 7: val_accuracy did not improve from 0.38333
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 902ms/step - accuracy: 0.3952 - loss: 1.4508 - val_accuracy: 0.3778 - val_loss: 1.4345 - learning_rate: 1.0000e-04
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 847ms/step - accuracy: 0.4225 - loss: 1.4440
# Epoch 8: val_accuracy did not improve from 0.38333
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 896ms/step - accuracy: 0.4226 - loss: 1.4423 - val_accuracy: 0.3222 - val_loss: 1.5034 - learning_rate: 1.0000e-04
# Epoch 9/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 832ms/step - accuracy: 0.4246 - loss: 1.3563
# Epoch 9: val_accuracy improved from 0.38333 to 0.40556, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - accuracy: 0.4246 - loss: 1.3554 - val_accuracy: 0.4056 - val_loss: 1.3955 - learning_rate: 1.0000e-04
# Epoch 10/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 843ms/step - accuracy: 0.4448 - loss: 1.3455
# Epoch 10: val_accuracy did not improve from 0.40556
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 891ms/step - accuracy: 0.4462 - loss: 1.3435 - val_accuracy: 0.3389 - val_loss: 1.6072 - learning_rate: 1.0000e-04
# Epoch 11/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.4361 - loss: 1.3590
# Epoch 11: val_accuracy improved from 0.40556 to 0.43333, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.4375 - loss: 1.3560 - val_accuracy: 0.4333 - val_loss: 1.4944 - learning_rate: 1.0000e-04
# Epoch 12/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 853ms/step - accuracy: 0.5248 - loss: 1.2693
# Epoch 12: val_accuracy did not improve from 0.43333
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 901ms/step - accuracy: 0.5244 - loss: 1.2695 - val_accuracy: 0.3500 - val_loss: 1.6485 - learning_rate: 1.0000e-04
# Epoch 13/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 815ms/step - accuracy: 0.4968 - loss: 1.2957
# Epoch 13: val_accuracy did not improve from 0.43333
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 902ms/step - accuracy: 0.4961 - loss: 1.2966 - val_accuracy: 0.4278 - val_loss: 1.3890 - learning_rate: 1.0000e-04
# Epoch 14/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.4864 - loss: 1.2720
# Epoch 14: val_accuracy improved from 0.43333 to 0.44444, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - accuracy: 0.4869 - loss: 1.2708 - val_accuracy: 0.4444 - val_loss: 1.3523 - learning_rate: 1.0000e-04
# Epoch 15/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.4469 - loss: 1.2914
# Epoch 15: val_accuracy did not improve from 0.44444
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 852ms/step - accuracy: 0.4484 - loss: 1.2885 - val_accuracy: 0.4444 - val_loss: 1.3525 - learning_rate: 1.0000e-04
# Epoch 16/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.5438 - loss: 1.1264
# Epoch 16: val_accuracy did not improve from 0.44444
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 861ms/step - accuracy: 0.5437 - loss: 1.1277 - val_accuracy: 0.4389 - val_loss: 1.3573 - learning_rate: 1.0000e-04
# Epoch 17/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 827ms/step - accuracy: 0.5138 - loss: 1.1855
# Epoch 17: val_accuracy improved from 0.44444 to 0.50556, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.5140 - loss: 1.1853 - val_accuracy: 0.5056 - val_loss: 1.2576 - learning_rate: 1.0000e-04
# Epoch 18/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 811ms/step - accuracy: 0.5121 - loss: 1.2000
# Epoch 18: val_accuracy improved from 0.50556 to 0.52222, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.5130 - loss: 1.1984 - val_accuracy: 0.5222 - val_loss: 1.2209 - learning_rate: 1.0000e-04
# Epoch 19/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.5585 - loss: 1.0644
# Epoch 19: val_accuracy did not improve from 0.52222
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 892ms/step - accuracy: 0.5589 - loss: 1.0644 - val_accuracy: 0.5167 - val_loss: 1.2462 - learning_rate: 1.0000e-04
# Epoch 20/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 820ms/step - accuracy: 0.5665 - loss: 1.1579
# Epoch 20: val_accuracy did not improve from 0.52222
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 893ms/step - accuracy: 0.5670 - loss: 1.1552 - val_accuracy: 0.5111 - val_loss: 1.2183 - learning_rate: 1.0000e-04
# Epoch 21/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 833ms/step - accuracy: 0.6015 - loss: 1.0210
# Epoch 21: val_accuracy did not improve from 0.52222
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 882ms/step - accuracy: 0.6012 - loss: 1.0218 - val_accuracy: 0.4444 - val_loss: 1.3676 - learning_rate: 1.0000e-04
# Epoch 22/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 837ms/step - accuracy: 0.5381 - loss: 1.1483
# Epoch 22: val_accuracy improved from 0.52222 to 0.52778, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - accuracy: 0.5393 - loss: 1.1467 - val_accuracy: 0.5278 - val_loss: 1.2962 - learning_rate: 1.0000e-04
# Epoch 23/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 811ms/step - accuracy: 0.5689 - loss: 1.0946
# Epoch 23: val_accuracy improved from 0.52778 to 0.53889, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.5690 - loss: 1.0933 - val_accuracy: 0.5389 - val_loss: 1.2331 - learning_rate: 1.0000e-04
# Epoch 24/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 861ms/step - accuracy: 0.5868 - loss: 1.0112
# Epoch 24: val_accuracy improved from 0.53889 to 0.56111, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.5859 - loss: 1.0128 - val_accuracy: 0.5611 - val_loss: 1.1292 - learning_rate: 1.0000e-04
# Epoch 25/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 761ms/step - accuracy: 0.5876 - loss: 1.0628
# Epoch 25: val_accuracy did not improve from 0.56111
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 808ms/step - accuracy: 0.5888 - loss: 1.0614 - val_accuracy: 0.5389 - val_loss: 1.1788 - learning_rate: 1.0000e-04
# Epoch 26/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 824ms/step - accuracy: 0.6130 - loss: 0.9648
# Epoch 26: val_accuracy did not improve from 0.56111
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 873ms/step - accuracy: 0.6124 - loss: 0.9654 - val_accuracy: 0.5278 - val_loss: 1.1658 - learning_rate: 1.0000e-04
# Epoch 27/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 781ms/step - accuracy: 0.5998 - loss: 1.0044
# Epoch 27: val_accuracy improved from 0.56111 to 0.56667, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.6008 - loss: 1.0031 - val_accuracy: 0.5667 - val_loss: 1.0954 - learning_rate: 1.0000e-04
# Epoch 28/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 826ms/step - accuracy: 0.5917 - loss: 0.9563
# Epoch 28: val_accuracy improved from 0.56667 to 0.60556, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - accuracy: 0.5928 - loss: 0.9550 - val_accuracy: 0.6056 - val_loss: 1.0015 - learning_rate: 1.0000e-04
# Epoch 29/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 845ms/step - accuracy: 0.6477 - loss: 0.9087
# Epoch 29: val_accuracy did not improve from 0.60556
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 893ms/step - accuracy: 0.6478 - loss: 0.9080 - val_accuracy: 0.5556 - val_loss: 1.0241 - learning_rate: 1.0000e-04
# Epoch 30/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 835ms/step - accuracy: 0.6810 - loss: 0.8064
# Epoch 30: val_accuracy improved from 0.60556 to 0.65556, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.6807 - loss: 0.8066 - val_accuracy: 0.6556 - val_loss: 0.9546 - learning_rate: 1.0000e-04
# Epoch 31/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 838ms/step - accuracy: 0.6708 - loss: 0.8301
# Epoch 31: val_accuracy did not improve from 0.65556
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 890ms/step - accuracy: 0.6708 - loss: 0.8305 - val_accuracy: 0.6222 - val_loss: 1.0322 - learning_rate: 1.0000e-04
# Epoch 32/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 795ms/step - accuracy: 0.6729 - loss: 0.8991
# Epoch 32: val_accuracy did not improve from 0.65556
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 844ms/step - accuracy: 0.6722 - loss: 0.8995 - val_accuracy: 0.5833 - val_loss: 0.9887 - learning_rate: 1.0000e-04
# Epoch 33/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 833ms/step - accuracy: 0.6665 - loss: 0.8200
# Epoch 33: val_accuracy did not improve from 0.65556
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 888ms/step - accuracy: 0.6670 - loss: 0.8190 - val_accuracy: 0.5833 - val_loss: 1.1021 - learning_rate: 1.0000e-04
# Epoch 34/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.6494 - loss: 0.8595
# Epoch 34: val_accuracy did not improve from 0.65556
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 854ms/step - accuracy: 0.6506 - loss: 0.8577 - val_accuracy: 0.5722 - val_loss: 1.0207 - learning_rate: 1.0000e-04
# Epoch 35/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 809ms/step - accuracy: 0.6985 - loss: 0.7225
# Epoch 35: val_accuracy did not improve from 0.65556
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 861ms/step - accuracy: 0.6977 - loss: 0.7239 - val_accuracy: 0.6389 - val_loss: 1.0061 - learning_rate: 1.0000e-04
# Epoch 36/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 842ms/step - accuracy: 0.7156 - loss: 0.7053
# Epoch 36: val_accuracy improved from 0.65556 to 0.71111, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - accuracy: 0.7162 - loss: 0.7041 - val_accuracy: 0.7111 - val_loss: 0.8583 - learning_rate: 5.0000e-05
# Epoch 37/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 853ms/step - accuracy: 0.7888 - loss: 0.5687
# Epoch 37: val_accuracy improved from 0.71111 to 0.73333, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.7887 - loss: 0.5689 - val_accuracy: 0.7333 - val_loss: 0.8270 - learning_rate: 5.0000e-05
# Epoch 38/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 817ms/step - accuracy: 0.7337 - loss: 0.6595
# Epoch 38: val_accuracy did not improve from 0.73333
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 865ms/step - accuracy: 0.7352 - loss: 0.6575 - val_accuracy: 0.6944 - val_loss: 0.8939 - learning_rate: 5.0000e-05
# Epoch 39/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 806ms/step - accuracy: 0.7605 - loss: 0.6003
# Epoch 39: val_accuracy did not improve from 0.73333
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 855ms/step - accuracy: 0.7619 - loss: 0.5976 - val_accuracy: 0.7056 - val_loss: 0.9304 - learning_rate: 5.0000e-05
# Epoch 40/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 822ms/step - accuracy: 0.8079 - loss: 0.5136
# Epoch 40: val_accuracy did not improve from 0.73333
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 901ms/step - accuracy: 0.8084 - loss: 0.5127 - val_accuracy: 0.6833 - val_loss: 0.8133 - learning_rate: 5.0000e-05
# Epoch 41/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 832ms/step - accuracy: 0.8188 - loss: 0.4832
# Epoch 41: val_accuracy did not improve from 0.73333
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 907ms/step - accuracy: 0.8183 - loss: 0.4835 - val_accuracy: 0.6778 - val_loss: 0.7771 - learning_rate: 5.0000e-05
# Epoch 42/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 834ms/step - accuracy: 0.7657 - loss: 0.5563
# Epoch 42: val_accuracy improved from 0.73333 to 0.73889, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.7669 - loss: 0.5556 - val_accuracy: 0.7389 - val_loss: 0.8523 - learning_rate: 5.0000e-05
# Epoch 43/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 838ms/step - accuracy: 0.8105 - loss: 0.5296
# Epoch 43: val_accuracy did not improve from 0.73889
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 889ms/step - accuracy: 0.8110 - loss: 0.5275 - val_accuracy: 0.7167 - val_loss: 0.8399 - learning_rate: 5.0000e-05
# Epoch 44/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 814ms/step - accuracy: 0.8354 - loss: 0.4470
# Epoch 44: val_accuracy improved from 0.73889 to 0.75000, saving model to vgg16_best_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - accuracy: 0.8359 - loss: 0.4468 - val_accuracy: 0.7500 - val_loss: 0.7131 - learning_rate: 5.0000e-05
# Epoch 45/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 816ms/step - accuracy: 0.8354 - loss: 0.4460
# Epoch 45: val_accuracy did not improve from 0.75000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 864ms/step - accuracy: 0.8355 - loss: 0.4458 - val_accuracy: 0.6833 - val_loss: 0.9270 - learning_rate: 5.0000e-05
# Epoch 46/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 881ms/step - accuracy: 0.8328 - loss: 0.4602
# Epoch 46: val_accuracy did not improve from 0.75000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 22s 930ms/step - accuracy: 0.8330 - loss: 0.4596 - val_accuracy: 0.6833 - val_loss: 1.0268 - learning_rate: 5.0000e-05
# Epoch 47/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.8014 - loss: 0.5362
# Epoch 47: val_accuracy did not improve from 0.75000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 867ms/step - accuracy: 0.8027 - loss: 0.5338 - val_accuracy: 0.7111 - val_loss: 0.8266 - learning_rate: 5.0000e-05
# Epoch 48/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 837ms/step - accuracy: 0.8371 - loss: 0.4324
# Epoch 48: val_accuracy did not improve from 0.75000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 889ms/step - accuracy: 0.8376 - loss: 0.4310 - val_accuracy: 0.7444 - val_loss: 0.7444 - learning_rate: 5.0000e-05
# Epoch 49/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 845ms/step - accuracy: 0.8618 - loss: 0.3508
# Epoch 49: val_accuracy improved from 0.75000 to 0.78333, saving model to vgg16_best_model.keras
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.8620 - loss: 0.3521 - val_accuracy: 0.7833 - val_loss: 0.8280 - learning_rate: 5.0000e-05
# Epoch 50/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 844ms/step - accuracy: 0.8711 - loss: 0.3372
# Epoch 50: val_accuracy did not improve from 0.78333
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 893ms/step - accuracy: 0.8714 - loss: 0.3365 - val_accuracy: 0.7667 - val_loss: 0.7485 - learning_rate: 2.5000e-05
# Restoring model weights from the end of the best epoch: 44.
# Model training complete and saved!
#
# Class mapping: {0: 'Moon_jellyfish', 1: 'barrel_jellyfish', 2: 'blue_jellyfish', 3: 'compass_jellyfish', 4: 'lions_mane_jellyfish', 5: 'mauve_stinger_jellyfish'}
